# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()

from scipy import stats
from scipy.stats import norm, skew
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_csv('../input/train.csv')
df_test = pd.read_csv('../input/test.csv')

# %% [markdown]
# # EDA

# %% [markdown]
# ## Descriptive Statistics

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
df_test.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704
# std       1.113740    30.390071     21.130467   177.625900   455.268042
# ...

# %%
#check the numbers of samples and features
print("The train data size before dropping Id : {} ".format(df_train.shape))
print("The test data size before dropping Id: {} ".format(df_test.shape))

#Keep 'Id' 
train_ID = df_train['Id']
test_ID = df_test['Id'] 

#drop the 'Id' colum from origina dataset
df_train.drop("Id", axis = 1, inplace = True)
df_test.drop("Id", axis = 1, inplace = True)

#check the numbers of samples and features without 'Id' 
print("The train data size after dropping Id: {} ".format(df_train.shape)) 
print("The test data size after dropping Id: {} ".format(df_test.shape))
# Out:
# The train data size before dropping Id : (1460, 81)
# The test data size before dropping Id: (1459, 80)
# The train data size after dropping Id: (1460, 80)
# The test data size after dropping Id: (1459, 79)

# %%
#identify numeric variables
numeric_features = df_train.select_dtypes(include=[np.number])
numeric_features.columns
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
#identify categorical variables
categorical_features = df_train.select_dtypes(include=[np.object])
categorical_features.columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
#missing data in training set
train_missing = df_train.isnull().sum().sort_values(ascending=False)
missing_percent = (df_train.isnull().sum()/df_train.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([train_missing, missing_percent], axis=1, keys=['TrainMissing', 'MissingPercent'])
missing_data.head(30)
# Out:
#               TrainMissing  MissingPercent
# PoolQC                1453        0.995205
# MiscFeature           1406        0.963014
# Alley                 1369        0.937671
# Fence                 1179        0.807534
# FireplaceQu            690        0.472603
# LotFrontage            259        0.177397
# GarageType              81        0.055479
# GarageCond              81        0.055479
# GarageFinish            81        0.055479
# GarageQual              81        0.055479
# GarageYrBlt             81        0.055479
# BsmtFinType2            38        0.026027
# BsmtExposure            38        0.026027
# BsmtQual                37        0.025342
# BsmtCond                37        0.025342
# BsmtFinType1            37        0.025342
# MasVnrArea               8        0.005479
# MasVnrType               8        0.005479
# Electrical               1        0.000685
# RoofMatl                 0        0.000000
# Exterior1st              0        0.000000
# ...

# %%
#descriptive statistics of the dependent variable
df_train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# ## Data Visualization

# %%
#histogram
sns.distplot(df_train['SalePrice'],fit=norm)
plt.title('SalePrice distribution')

#normal prob plot
fig = plt.figure()
res = stats.probplot(df_train['SalePrice'], plot=plt)
plt.show()

# %%
#saleprice correlation matrix
corrmat = df_train.corr()
k = 10 #number of variables for heatmap
cols = corrmat.nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(df_train[cols].values.T)
sns.set(font_scale=1)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
hm.set_title('SalePrice Correlation')
plt.show()

# %%
#scatterplot
sns.set()
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sns.pairplot(df_train[cols], size = 5,kind ='reg')
plt.show();

# %%
#scatter plot grlivarea/saleprice
fig, ax = plt.subplots()
ax.scatter(x = df_train['GrLivArea'], y = df_train['SalePrice'])
plt.ylabel('SalePrice', fontsize=12)
plt.xlabel('GrLivArea', fontsize=12)
plt.show()

# %%
#Deleting outliers
df_train = df_train.drop(df_train[(df_train['GrLivArea']>4000) & (df_train['SalePrice']<300000)].index)

#Check the graphic again
fig, ax = plt.subplots()
ax.scatter(df_train['GrLivArea'], df_train['SalePrice'])
plt.ylabel('SalePrice', fontsize=12)
plt.xlabel('GrLivArea', fontsize=12)
plt.show()

# %%
#scatter plot totalbsmtsf/saleprice
fig, ax = plt.subplots()
ax.scatter(x = df_train['TotalBsmtSF'], y = df_train['SalePrice'])
plt.ylabel('SalePrice', fontsize=12)
plt.xlabel('TotalBsmtSF', fontsize=12)
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
# concatenate train and test data
number_train = df_train.shape[0]
number_test = df_test.shape[0]
all_data = pd.concat((df_train, df_test)).reset_index(drop=True)
all_data.drop(['SalePrice'], axis=1, inplace=True)
print("all_data size: {}".format(all_data.shape))
# Out:
# all_data size: (2917, 79)

# %%
all_missing = all_data.isnull().sum().sort_values(ascending=False)
missing_percent = (all_data.isnull().sum()/all_data.isnull().count()).sort_values(ascending=False) *100
missing_data = pd.concat([all_missing, missing_percent], axis=1, keys=['ALLMissing', 'MissingPercent'])
missing_data.head(35)
# Out:
#               ALLMissing  MissingPercent
# PoolQC              2908       99.691464
# MiscFeature         2812       96.400411
# Alley               2719       93.212204
# Fence               2346       80.425094
# FireplaceQu         1420       48.680151
# LotFrontage          486       16.660953
# GarageFinish         159        5.450806
# GarageQual           159        5.450806
# GarageYrBlt          159        5.450806
# GarageCond           159        5.450806
# GarageType           157        5.382242
# BsmtCond              82        2.811107
# BsmtExposure          82        2.811107
# BsmtQual              81        2.776826
# BsmtFinType2          80        2.742544
# BsmtFinType1          79        2.708262
# MasVnrType            24        0.822763
# MasVnrArea            23        0.788481
# MSZoning               4        0.137127
# BsmtHalfBath           2        0.068564
# Utilities              2        0.068564
# Functional             2        0.068564
# ...

# %%
#input missing value
all_data["PoolQC"] = all_data["PoolQC"].fillna("None")
all_data["MiscFeature"] = all_data["MiscFeature"].fillna("None")
all_data["Alley"] = all_data["Alley"].fillna("None")
all_data["Fence"] = all_data["Fence"].fillna("None")
all_data["FireplaceQu"] = all_data["FireplaceQu"].fillna("None")
all_data["LotFrontage"] = all_data["LotFrontage"].fillna(all_data["LotFrontage"].median())

for var in ('GarageType', 'GarageFinish', 'GarageQual', 'GarageCond','BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'):
    all_data[var] = all_data[var].fillna('None')

for var in ('GarageYrBlt', 'GarageArea', 'GarageCars','BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath'):
    all_data[var] = all_data[var].fillna(0)
    
all_data["MasVnrType"] = all_data["MasVnrType"].fillna("None")
all_data["MasVnrArea"] = all_data["MasVnrArea"].fillna(0)
all_data['MSZoning'] = all_data['MSZoning'].fillna(all_data['MSZoning'].mode()[0])
all_data = all_data.drop(['Utilities'], axis=1)
all_data["Functional"] = all_data["Functional"].fillna("Typ")


all_data['Electrical'] = all_data['Electrical'].fillna(all_data['Electrical'].mode()[0])
all_data['KitchenQual'] = all_data['KitchenQual'].fillna(all_data['KitchenQual'].mode()[0])
all_data['Exterior1st'] = all_data['Exterior1st'].fillna(all_data['Exterior1st'].mode()[0])
all_data['Exterior2nd'] = all_data['Exterior2nd'].fillna(all_data['Exterior2nd'].mode()[0])
all_data['SaleType'] = all_data['SaleType'].fillna(all_data['SaleType'].mode()[0])

all_data['MSSubClass'] = all_data['MSSubClass'].fillna("None")

# %%
#check if there are still missing values 
all_missing = all_data.isnull().sum().sort_values(ascending=False)
missing_percent = (all_data.isnull().sum()/all_data.isnull().count()).sort_values(ascending=False) *100
missing_data = pd.concat([all_missing, missing_percent], axis=1, keys=['ALLMissing', 'MissingPercent'])
missing_data.head(10)
# Out:
#              ALLMissing  MissingPercent
# YrSold                0             0.0
# Foundation            0             0.0
# ExterCond             0             0.0
# ExterQual             0             0.0
# Exterior1st           0             0.0
# Exterior2nd           0             0.0
# Fence                 0             0.0
# FireplaceQu           0             0.0
# Fireplaces            0             0.0
# FullBath              0             0.0

# %%
#Transforming some numerical variables that are really categorical to categorical variables

#MSSubClass
all_data['MSSubClass'] = all_data['MSSubClass'].apply(str)

#OverallCond
all_data['OverallCond'] = all_data['OverallCond'].astype(str)

#Year and month sold
all_data['YrSold'] = all_data['YrSold'].astype(str)
all_data['MoSold'] = all_data['MoSold'].astype(str)

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder

var = ('FireplaceQu', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond', 
        'ExterQual', 'ExterCond','HeatingQC', 'PoolQC', 'KitchenQual', 'BsmtFinType1', 
        'BsmtFinType2', 'Functional', 'Fence', 'BsmtExposure', 'GarageFinish', 'LandSlope',
        'LotShape', 'PavedDrive', 'Street', 'Alley', 'CentralAir', 'MSSubClass', 'OverallCond', 
        'YrSold', 'MoSold')

for v in var:
    lbl = LabelEncoder() 
    lbl.fit(list(all_data[v].values)) 
    all_data[v] = lbl.transform(list(all_data[v].values))

# %%
naive_df_train = df_train.copy()
naive_df_test = df_test.copy()
naive_df_train['SalePrice'] = np.log1p(df_train['SalePrice'].mean())
naive_y = naive_df_train['SalePrice'].values
naive_y.shape
# Out:
# (1458,)

# %%
#Transform skewed variables

#Saleprice
df_train['SalePrice'] = np.log1p(df_train['SalePrice'])
sns.distplot(df_train['SalePrice'] , fit=norm)
fig = plt.figure()
res = stats.probplot(df_train['SalePrice'], plot=plt)
y = df_train.SalePrice.values

# %%
# Check the skew of all numerical variables
numeric_var = all_data.dtypes[all_data.dtypes != "object"].index
skewed_var = all_data[numeric_var].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
skewed_var = skewed_var[abs(skewed_var) > 0.5]
skewed_var = skewed_var.index

from scipy.special import boxcox1p
lam = 0.15
all_data[skewed_var] = boxcox1p(all_data[skewed_var],lam)

# %%
#dummy variables
all_data = pd.get_dummies(all_data)

# %%
#split the train and test set
df_train = all_data[:number_train]
df_test = all_data[number_train:]
print(df_train.shape)
print(df_test.shape)
# Out:
# (1458, 219)
# (1459, 219)

# %% [markdown]
# # Modeling

# %%
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, RidgeCV, Lasso, ElasticNetCV, LassoCV
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error

from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone


# !pip install xgboost
import xgboost as xgb

# conda install -c conda-forge lightgbm 
# import lightgbm as lgb

# %%
X_train,X_test,y_train,y_test = train_test_split(df_train,y,test_size = 0.3,random_state= 100)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((1020, 219), (438, 219), (1020,), (438,))

# %%
#Define error measure for official scoring : RMSE
#Validation function

from sklearn.metrics import make_scorer
scorer = make_scorer(mean_squared_error,greater_is_better = False)
def rmse_cv_train(model):
    rmse = np.sqrt(-cross_val_score(model,X_train,y_train,scoring =scorer,cv=10))
    return (rmse)
def rmse_cv_test(model):
    rmse = np.sqrt(-cross_val_score(model,X_test,y_test,scoring =scorer,cv=10))
    return (rmse)

# %% [markdown]
# ### Naive Model

# %%
naive_X_train,naive_X_test,naive_y_train,naive_y_test = train_test_split(df_train,naive_y,test_size = 0.3,random_state= 100)
naive_X_train.shape,naive_X_test.shape,naive_y_train.shape,naive_y_test.shape

from sklearn.metrics import mean_squared_error
print('RMSE on train:', mean_squared_error(naive_y_train, y_train))
print('RMSE on test:', mean_squared_error(naive_y_test, y_test))
# Out:
# RMSE on train: 0.16952062070851281
# RMSE on test: 0.15901225665272464

# %%
"""
lr = LinearRegression()
lr.fit(X_train, y_train)

print('RMSE on train:', rmse_cv_train(lr).mean())
print('RMSE on test:', rmse_cv_test(lr).mean())
y_train_pred = lr.predict(X_train)
y_test_pred = lr.predict(X_test)
"""
# Out:
# "\nlr = LinearRegression()\nlr.fit(X_train, y_train)\n\nprint('RMSE on train:', rmse_cv_train(lr).mean())\nprint('RMSE on test:', rmse_cv_test(lr).mean())\ny_train_pred = lr.predict(X_train)\ny_test_pred = lr.predict(X_test)\n"

# %% [markdown]
# ###  Linear Regression with Ridge regularization

# %%
# find the best alpha
ridge = RidgeCV(alphas = [0.01, 0.03, 0.06, 0.1, 0.3, 0.6, 1, 3, 6, 10, 30, 60],cv = 5)
ridge.fit(X_train, y_train)
alpha = ridge.alpha_
print("The best alpha :", alpha)

print("Ridge RMSE on train:", rmse_cv_train(ridge).mean())
print("Ridge RMSE on test:", rmse_cv_test(ridge).mean())

coef = pd.Series(ridge.coef_, index = X_train.columns)
print("Ridge picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  \
      str(sum(coef == 0)) + " variables")

# Plot important coefficients
imp_coef = pd.concat([coef.sort_values().head(10),
                     coef.sort_values().tail(10)])
imp_coef.plot(kind = "barh")
plt.title("Important Coefficients in the Ridge Model")
plt.show()
# Out:
# The best alpha : 10
# Ridge RMSE on train: 0.11522294591213526
# Ridge RMSE on test: 0.1307009094600428
# Ridge picked 214 variables and eliminated the other 5 variables

# %% [markdown]
# ### Linear Regression with Lasso regularization

# %%
# find the best alpha
lasso = LassoCV(alphas = [0.0001, 0.0003, 0.0006, 0.001, 0.003, 0.006, 0.01, 0.03, 0.06, 0.1, 
                          0.3, 0.6, 1], 
                max_iter = 50000, cv = 5)
lasso.fit(X_train, y_train)
alpha = lasso.alpha_
print("The best alpha :", alpha)

print("Lasso RMSE on train:", rmse_cv_train(lasso).mean())
print("Lasso RMSE on test:", rmse_cv_test(lasso).mean())

coef = pd.Series(lasso.coef_, index = X_train.columns)
print("Lasso picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  \
      str(sum(coef == 0)) + " variables")

# Plot important coefficients
imp_coef = pd.concat([coef.sort_values().head(10),
                     coef.sort_values().tail(10)])
imp_coef.plot(kind = "barh")
plt.title("Important Coefficients in the Ridge Model")
plt.show()
# Out:
# The best alpha : 0.0006
# Lasso RMSE on train: 0.11784752330898898
# Lasso RMSE on test: 0.13070360975288497
# Lasso picked 94 variables and eliminated the other 125 variables

# %% [markdown]
#  ### Linear Regression with ElasticNet regularization

# %%
ENet = ElasticNetCV(l1_ratio = [0.1, 0.3, 0.5, 0.6, 0.7, 0.8, 0.85, 0.9, 0.95, 1],
                          alphas = [0.0001, 0.0003, 0.0006, 0.001, 0.003, 0.006, 
                                    0.01, 0.03, 0.06, 0.1, 0.3, 0.6, 1, 3, 6], 
                          max_iter = 50000, cv = 10)
ENet.fit(X_train, y_train)
alpha = ENet.alpha_
ratio = ENet.l1_ratio_
print("The best l1_ratio :", ratio)
print("The best alpha :", alpha )

print("ElasticNet RMSE on train:", rmse_cv_train(ENet).mean())
print("ElasticNet RMSE on test:", rmse_cv_test(ENet).mean())

coef = pd.Series(ENet.coef_, index = X_train.columns)
print("ENet picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  \
      str(sum(coef == 0)) + " variables")

# Plot important coefficients
imp_coef = pd.concat([coef.sort_values().head(10),
                     coef.sort_values().tail(10)])
imp_coef.plot(kind = "barh")
plt.title("Important Coefficients in the ElasticNet Model")
plt.show()
# Out:
# The best l1_ratio : 0.1
# The best alpha : 0.003
# ElasticNet RMSE on train: 0.11523328516889993
# ElasticNet RMSE on test: 0.13311241519067668
# ENet picked 118 variables and eliminated the other 101 variables

# %% [markdown]
# ### Xgboost

# %%
xgboost = xgb.XGBRegressor(learning_rate=0.05, n_estimators=1000,random_state=5)
xgboost.fit(X_train, y_train)
print("Xgboost RMSE on train:", rmse_cv_train(xgboost).mean())
print("Xgboost RMSE on test:", rmse_cv_test(xgboost).mean())
# Out:
# Xgboost RMSE on train: 0.12161503326700931
# Xgboost RMSE on test: 0.13609703821737423

# %% [markdown]
# ## Model Tunning

# %% [markdown]
# ### ridge

# %%
# find the best alpha
ridge = RidgeCV(alphas = [0.01, 0.03, 0.06, 0.1, 0.3, 0.6, 1, 3, 6, 10, 30, 60],cv = 5)
ridge.fit(X_train, y_train)
alpha = ridge.alpha_
print("The best alpha :", alpha)

# find a more accurate alpha
ridge = RidgeCV(alphas = [alpha * .6, alpha * .65, alpha * .7, alpha * .75, alpha * .8, alpha * .85, 
                          alpha * .9, alpha * .95, alpha, alpha * 1.05, alpha * 1.1, alpha * 1.15,
                          alpha * 1.25, alpha * 1.3, alpha * 1.35, alpha * 1.4], 
                cv = 5)
ridge.fit(X_train, y_train)
alpha = ridge.alpha_
print("The new best alpha :", alpha)

print("Ridge RMSE on train:", rmse_cv_train(ridge).mean())
print("Ridge RMSE on test:", rmse_cv_test(ridge).mean())

coef = pd.Series(ridge.coef_, index = X_train.columns)
print("Ridge picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  \
      str(sum(coef == 0)) + " variables")

# Plot important coefficients
imp_coef = pd.concat([coef.sort_values().head(10),
                     coef.sort_values().tail(10)])
imp_coef.plot(kind = "barh")
plt.title("Important Coefficients in the Ridge Model")
plt.show()
# Out:
# The best alpha : 10
# The new best alpha : 11.5
# Ridge RMSE on train: 0.11548967513711661
# Ridge RMSE on test: 0.13008009968381853
# Ridge picked 214 variables and eliminated the other 5 variables

# %% [markdown]
# ### lasso

# %%
# find the best alpha
lasso = LassoCV(alphas = [0.0001, 0.0003, 0.0006, 0.001, 0.003, 0.006, 0.01, 0.03, 0.06, 0.1, 
                          0.3, 0.6, 1], 
                max_iter = 50000, cv = 5)
lasso.fit(X_train, y_train)
alpha = lasso.alpha_
print("The best alpha :", alpha)

# find a more accurate alpha
lasso = LassoCV(alphas = [alpha * .6, alpha * .65, alpha * .7, alpha * .75, alpha * .8, 
                          alpha * .85, alpha * .9, alpha * .95, alpha, alpha * 1.05, 
                          alpha * 1.1, alpha * 1.15, alpha * 1.25, alpha * 1.3, alpha * 1.35, 
                          alpha * 1.4], 
                max_iter = 50000, cv = 5)
lasso.fit(X_train, y_train)
alpha = lasso.alpha_
print("The new best alpha :", alpha)

print("Lasso RMSE on Training set :", rmse_cv_train(lasso).mean())
print("Lasso RMSE on Test set :", rmse_cv_test(lasso).mean())

coef = pd.Series(lasso.coef_, index = X_train.columns)
print("Lasso picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  \
      str(sum(coef == 0)) + " variables")

# Plot important coefficients
imp_coef = pd.concat([coef.sort_values().head(10),
                     coef.sort_values().tail(10)])
imp_coef.plot(kind = "barh")
plt.title("Important Coefficients in the laaso Model")
plt.show()
# Out:
# The best alpha : 0.0006
# The new best alpha : 0.0005099999999999999
# Lasso RMSE on Training set : 0.1159734100023283
# Lasso RMSE on Test set : 0.12987941311617346
# Lasso picked 96 variables and eliminated the other 123 variables

# %% [markdown]
# ### ENet

# %%
ENet = ElasticNetCV(l1_ratio = [0.1, 0.3, 0.5, 0.6, 0.7, 0.8, 0.85, 0.9, 0.95, 1],
                          alphas = [0.0001, 0.0003, 0.0006, 0.001, 0.003, 0.006, 
                                    0.01, 0.03, 0.06, 0.1, 0.3, 0.6, 1, 3, 6], 
                          max_iter = 50000, cv = 10)
ENet.fit(X_train, y_train)
alpha = ENet.alpha_
ratio = ENet.l1_ratio_

# find a more accurate l1_ratio
ENet = ElasticNetCV(l1_ratio = [ratio * .85, ratio * .9, ratio * .95, ratio, ratio * 1.05, ratio * 1.1, ratio * 1.15],
                          alphas = [0.0001, 0.0003, 0.0006, 0.001, 0.003, 0.006, 0.01, 0.03, 0.06, 0.1, 0.3, 0.6, 1, 3, 6], 
                          max_iter = 50000, cv = 10)
ENet.fit(X_train, y_train)
if (ENet.l1_ratio_ > 1):
    ENet.l1_ratio_ = 1    
alpha = ENet.alpha_
ratio = ENet.l1_ratio_
print("The new best l1_ratio :", ratio)

# find a more accurate alpha
ENet = ElasticNetCV(l1_ratio = ratio,
                          alphas = [alpha * .6, alpha * .65, alpha * .7, alpha * .75, alpha * .8, alpha * .85, alpha * .9, 
                                    alpha * .95, alpha, alpha * 1.05, alpha * 1.1, alpha * 1.15, alpha * 1.25, alpha * 1.3, 
                                    alpha * 1.35, alpha * 1.4], 
                          max_iter = 50000, cv = 10)
ENet.fit(X_train, y_train)
if (ENet.l1_ratio_ > 1):
    ENet.l1_ratio_ = 1    
alpha = ENet.alpha_
ratio = ENet.l1_ratio_
print("The new best l1_ratio :", ratio)
print("The new best alpha :", alpha )


print("ElasticNet RMSE on train:", rmse_cv_train(ENet).mean())
print("ElasticNet RMSE on test:", rmse_cv_test(ENet).mean())

coef = pd.Series(ENet.coef_, index = X_train.columns)
print("ENet picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  \
      str(sum(coef == 0)) + " variables")


# Plot important coefficients
imp_coef = pd.concat([coef.sort_values().head(10),
                     coef.sort_values().tail(10)])
imp_coef.plot(kind = "barh")
plt.title("Important Coefficients in the ElasticNet Model")
plt.show()
# Out:
# The new best l1_ratio : 0.11499999999999999
# The new best l1_ratio : 0.11499999999999999
# The new best alpha : 0.0033000000000000004
# ElasticNet RMSE on train: 0.11538419406499564
# ElasticNet RMSE on test: 0.1312692075549454
# ENet picked 109 variables and eliminated the other 110 variables

# %% [markdown]
# ### XGboost

# %%
xgboost = xgb.XGBRegressor(learning_rate=0.02, n_estimators=2000,random_state=5)
xgboost.fit(X_train, y_train)
print("Xgboost RMSE on train:", rmse_cv_train(xgboost).mean())
print("Xgboost RMSE on test:", rmse_cv_test(xgboost).mean())
# Out:
# Xgboost RMSE on train: 0.12018690687739941
# Xgboost RMSE on test: 0.13594258950123086

# %% [markdown]
# ## Ensembling Model

# %%
Enet_pred= np.expm1(ENet.predict(df_test.values))

# %%
xgb_pred = np.expm1(xgboost.predict(df_test))

# %%
ensemble = xgb_pred*0.3 + Enet_pred*0.7

# %%
sub = pd.DataFrame()
sub['Id'] = test_ID
sub['SalePrice'] = ensemble
sub.to_csv('../output/submission.csv',index=False)
